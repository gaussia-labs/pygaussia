# %% [markdown]
# # Gaussia Generators - Groq Example
#
# This notebook demonstrates how to use the Gaussia generators module with **Groq Cloud** for ultra-fast synthetic test dataset generation.
#
# ## Overview
#
# The `BaseGenerator` class accepts any LangChain-compatible chat model, including Groq's `ChatGroq`. This provides extremely fast inference for open-source LLMs.
#
# ### Why Groq?
# - **Speed**: Up to 10x faster than traditional cloud providers
# - **Cost**: Competitive pricing for high-volume usage
# - **Models**: Access to popular open-source models (Llama 3, Mixtral, Gemma)

# %% [markdown]
# ## Installation
# First, install Gaussia with Alquimia support and required dependencies.

# %%
# !pip install "gaussia[generators]" langchain-groq -q

# %% [markdown]
# ## Setup

# %%
import json
import time
from pathlib import Path

from dotenv import load_dotenv
from langchain_groq import ChatGroq

from gaussia.generators import (
    BaseGenerator,
    # Strategies for chunk selection
    RandomSamplingStrategy,
    create_markdown_loader,
)

# Load environment variables
load_dotenv()
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# Imports loaded successfully

# %% [markdown]
# ## Create Sample Content
#
# Let's create a sample markdown document for testing:

# %%
sample_content = """# Machine Learning Fundamentals

This guide covers the basics of machine learning for beginners.

## Types of Machine Learning

Machine learning can be categorized into three main types:

### Supervised Learning
- Uses labeled training data
- Predicts outcomes based on input features
- Examples: Classification, Regression

### Unsupervised Learning
- Works with unlabeled data
- Discovers hidden patterns and structures
- Examples: Clustering, Dimensionality Reduction

### Reinforcement Learning
- Agent learns through interaction with environment
- Maximizes cumulative reward
- Examples: Game playing, Robotics

## Model Evaluation

Key metrics for evaluating ML models:

- **Accuracy**: Proportion of correct predictions
- **Precision**: True positives among predicted positives
- **Recall**: True positives among actual positives
- **F1 Score**: Harmonic mean of precision and recall

## Best Practices

1. Split data into train/validation/test sets
2. Use cross-validation for robust evaluation
3. Monitor for overfitting
4. Document your experiments
"""

# Save to file
sample_file = Path("./ml_fundamentals.md")
sample_file.write_text(sample_content)
print(f"Sample content saved to: {sample_file}")
# Out:
# Sample content saved to: ml_fundamentals.md

# %% [markdown]
# ## Create Context Loader

# %%
# Create markdown loader
loader = create_markdown_loader(
    max_chunk_size=2000,
    header_levels=[1, 2, 3],
)

# Preview chunks
chunks = loader.load(str(sample_file))
print(f"Created {len(chunks)} chunks:\n")
for chunk in chunks:
    print(f"- {chunk.chunk_id}: {len(chunk.content)} chars")
# Out:
# 2026-01-15 17:10:17.654 | INFO     | gaussia.generators:create_markdown_loader:141 - Creating local markdown loader
# 2026-01-15 17:10:17.656 | INFO     | gaussia.generators.context_loaders.local_markdown:load:275 - Loading 1 markdown file(s)
# 2026-01-15 17:10:17.657 | INFO     | gaussia.generators.context_loaders.local_markdown:_load_single_file:137 - Loading markdown file: ml_fundamentals.md
# 2026-01-15 17:10:17.660 | INFO     | gaussia.generators.context_loaders.local_markdown:load:282 - Created 7 total chunks from 1 file(s)
# Created 7 chunks:
#
# - ml_fundamentals_machine_learning_fundamentals: 63 chars
# - ml_fundamentals_types_of_machine_learning: 58 chars
# - ml_fundamentals_supervised_learning: 111 chars
# - ml_fundamentals_unsupervised_learning: 119 chars
# - ml_fundamentals_reinforcement_learning: 116 chars
# - ml_fundamentals_model_evaluation: 252 chars
# - ml_fundamentals_best_practices: 147 chars

# %% [markdown]
# ## Create Generator with Groq Model
#
# The `BaseGenerator` accepts any LangChain-compatible chat model. Here we use `ChatGroq` from `langchain-groq`.

# %%
# Create Groq model using LangChain
model = ChatGroq(
    model="llama-3.1-8b-instant",  # Fast model for demos
    temperature=0.4,
    max_tokens=2048,
)

# Create generator with the model
generator = BaseGenerator(
    model=model,
    use_structured_output=True,
)

print(f"Generator created with model: {model.model_name}")
# Out:
# Generator created with model: llama-3.1-8b-instant

# %% [markdown]
# ## Generate Test Dataset
#
# Groq's fast inference makes generation very quick!

# %%
async def generate_dataset():
    print("Generating test dataset with Groq...\n")

    start_time = time.time()

    # generate_dataset returns list[Dataset]
    datasets = await generator.generate_dataset(
        context_loader=loader,
        source=str(sample_file),
        assistant_id="ml-assistant",
        num_queries_per_chunk=3,
        language="english",
    )

    elapsed = time.time() - start_time

    # With default SequentialStrategy, we get one dataset
    dataset = datasets[0]

    print(f"Generated {len(datasets)} dataset(s) in {elapsed:.2f} seconds:")
    print(f"  Session ID: {dataset.session_id}")
    print(f"  Total queries: {len(dataset.conversation)}\n")

    print("Generated queries:")
    for batch in dataset.conversation:
        difficulty = batch.agentic.get("difficulty", "N/A")
        query_type = batch.agentic.get("query_type", "N/A")
        print(f"  [{batch.qa_id}] ({difficulty}/{query_type})")
        print(f"    {batch.query}\n")

    return datasets


# Execute
datasets = await generate_dataset()
dataset = datasets[0]
# Out:
# 2026-01-15 17:10:18.210 | INFO     | gaussia.schemas.generators:generate_dataset:525 - Loading context from: ml_fundamentals.md
# 2026-01-15 17:10:18.211 | INFO     | gaussia.generators.context_loaders.local_markdown:load:275 - Loading 1 markdown file(s)
# 2026-01-15 17:10:18.212 | INFO     | gaussia.generators.context_loaders.local_markdown:_load_single_file:137 - Loading markdown file: ml_fundamentals.md
# 2026-01-15 17:10:18.213 | INFO     | gaussia.generators.context_loaders.local_markdown:load:282 - Created 7 total chunks from 1 file(s)
# 2026-01-15 17:10:18.214 | INFO     | gaussia.schemas.generators:generate_dataset:527 - Loaded 7 chunks from source
# 2026-01-15 17:10:18.215 | INFO     | gaussia.schemas.generators:generate_dataset:531 - Using chunk selection strategy: SequentialStrategy()
# 2026-01-15 17:10:18.216 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 3 queries for chunk ml_fundamentals_machine_learning_fundamentals
# Generating test dataset with Groq...
# 2026-01-15 17:10:19,305 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:19.321 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 3 queries for chunk ml_fundamentals_machine_learning_fundamentals
# 2026-01-15 17:10:19.321 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 3 queries for chunk ml_fundamentals_types_of_machine_learning
# 2026-01-15 17:10:20,042 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:20.046 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 3 queries for chunk ml_fundamentals_types_of_machine_learning
# 2026-01-15 17:10:20.047 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 3 queries for chunk ml_fundamentals_supervised_learning
# 2026-01-15 17:10:20,656 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:20.659 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 1 queries for chunk ml_fundamentals_supervised_learning
# 2026-01-15 17:10:20.661 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 3 queries for chunk ml_fundamentals_unsupervised_learning
# 2026-01-15 17:10:21,289 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:21.292 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 3 queries for chunk ml_fundamentals_unsupervised_learning
# 2026-01-15 17:10:21.293 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 3 queries for chunk ml_fundamentals_reinforcement_learning
# 2026-01-15 17:10:21,992 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:21.995 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 3 queries for chunk ml_fundamentals_reinforcement_learning
# 2026-01-15 17:10:21.996 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 3 queries for chunk ml_fundamentals_model_evaluation
# 2026-01-15 17:10:22,606 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:22.609 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 3 queries for chunk ml_fundamentals_model_evaluation
# 2026-01-15 17:10:22.610 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 3 queries for chunk ml_fundamentals_best_practices
# 2026-01-15 17:10:23,336 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:23.339 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 3 queries for chunk ml_fundamentals_best_practices
# 2026-01-15 17:10:23.341 | INFO     | gaussia.schemas.generators:generate_dataset:586 - Generated 19 batches for chunk group (7 chunks)
# 2026-01-15 17:10:23.342 | INFO     | gaussia.schemas.generators:generate_dataset:600 - Generated 1 dataset(s) with 19 total batches
# Generated 1 dataset(s) in 5.13 seconds:
#   Session ID: e51451eb-f4f5-4917-885b-efadb4ecfe0d
#   Total queries: 19
#
# Generated queries:
#   [ml_fundamentals_machine_learning_fundamentals_q1] (medium/factual)
#     What are the fundamental concepts of machine learning?
#
#   [ml_fundamentals_machine_learning_fundamentals_q2] (hard/application)
#     How can you apply machine learning in real-world scenarios?
#
#   [ml_fundamentals_machine_learning_fundamentals_q3] (medium/comparative)
#     What are the key differences between supervised and unsupervised learning?
#
#   [ml_fundamentals_types_of_machine_learning_q1] (easy/factual)
#     What are the three main types of machine learning?
#
#   [ml_fundamentals_types_of_machine_learning_q2] (medium/application)
#     How can machine learning be applied in real-world scenarios?
#
#   [ml_fundamentals_types_of_machine_learning_q3] (hard/comparative)
#     What are the key differences between supervised and unsupervised machine learning?
#
#   [ml_fundamentals_supervised_learning_q1] (N/A/factual)
#     What type of tasks does the model perform?
#
#   [ml_fundamentals_unsupervised_learning_q1] (medium/application)
#     What are some common applications of clustering in data analysis?
#
#   [ml_fundamentals_unsupervised_learning_q2] (hard/inferential)
#     How does dimensionality reduction help in identifying hidden patterns in data?
#
#   [ml_fundamentals_unsupervised_learning_q3] (medium/comparative)
#     What are some key differences between clustering and dimensionality reduction?
#
#   [ml_fundamentals_reinforcement_learning_q1] (medium/factual)
#     How does an agent learn through interaction with its environment?
#
#   [ml_fundamentals_reinforcement_learning_q2] (N/A/factual)
#     What are some examples of environments where an agent can maximize cumulative reward?
#
#   [ml_fundamentals_reinforcement_learning_q3] (hard/application)
#     How can we design an environment to test an agent's ability to apply its learned knowledge?
#
#   [ml_fundamentals_model_evaluation_q1] (easy/factual)
#     What are the key metrics used to evaluate ML models?
#
#   [ml_fundamentals_model_evaluation_q2] (medium/inferential)
#     How do you interpret the F1 Score in the context of ML model evaluation?
#
#   [ml_fundamentals_model_evaluation_q3] (hard/comparative)
#     Compare and contrast the concepts of precision and recall in ML model evaluation.
#
#   [ml_fundamentals_best_practices_q1] (medium/factual)
#     What are the typical steps involved in splitting data for machine learning?
#
#   [ml_fundamentals_best_practices_q2] (hard/inferential)
#     How does cross-validation help in evaluating model performance?
#
#   [ml_fundamentals_best_practices_q3] (medium/comparative)
#     What are some common strategies for preventing overfitting in machine learning models?

# %% [markdown]
# ## Generate with Seed Examples

# %%
async def generate_with_seeds():
    seed_examples = [
        "What is the difference between supervised and unsupervised learning?",
        "How do you prevent overfitting in a machine learning model?",
        "When should you use precision vs recall as your primary metric?",
    ]

    print("Generating with seed examples...\n")

    datasets = await generator.generate_dataset(
        context_loader=loader,
        source=str(sample_file),
        assistant_id="ml-assistant",
        num_queries_per_chunk=2,
        seed_examples=seed_examples,
    )

    dataset = datasets[0]
    print(f"Generated {len(dataset.conversation)} queries:")
    for batch in dataset.conversation[:5]:
        print(f"  - {batch.query}")

    return datasets


# Execute
datasets_with_seeds = await generate_with_seeds()
# Out:
# 2026-01-15 17:10:23.351 | INFO     | gaussia.schemas.generators:generate_dataset:525 - Loading context from: ml_fundamentals.md
# 2026-01-15 17:10:23.352 | INFO     | gaussia.generators.context_loaders.local_markdown:load:275 - Loading 1 markdown file(s)
# 2026-01-15 17:10:23.352 | INFO     | gaussia.generators.context_loaders.local_markdown:_load_single_file:137 - Loading markdown file: ml_fundamentals.md
# 2026-01-15 17:10:23.354 | INFO     | gaussia.generators.context_loaders.local_markdown:load:282 - Created 7 total chunks from 1 file(s)
# 2026-01-15 17:10:23.354 | INFO     | gaussia.schemas.generators:generate_dataset:527 - Loaded 7 chunks from source
# 2026-01-15 17:10:23.355 | INFO     | gaussia.schemas.generators:generate_dataset:531 - Using chunk selection strategy: SequentialStrategy()
# 2026-01-15 17:10:23.355 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_machine_learning_fundamentals
# Generating with seed examples...
# 2026-01-15 17:10:23,829 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:23.831 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 2 queries for chunk ml_fundamentals_machine_learning_fundamentals
# 2026-01-15 17:10:23.832 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_types_of_machine_learning
# 2026-01-15 17:10:24,367 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:24.371 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 2 queries for chunk ml_fundamentals_types_of_machine_learning
# 2026-01-15 17:10:24.372 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_supervised_learning
# 2026-01-15 17:10:24,957 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:24.960 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 1 queries for chunk ml_fundamentals_supervised_learning
# 2026-01-15 17:10:24.961 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_unsupervised_learning
# 2026-01-15 17:10:25,469 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:25.473 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 2 queries for chunk ml_fundamentals_unsupervised_learning
# 2026-01-15 17:10:25.474 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_reinforcement_learning
# 2026-01-15 17:10:25,982 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:25.985 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 2 queries for chunk ml_fundamentals_reinforcement_learning
# 2026-01-15 17:10:25.987 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_model_evaluation
# 2026-01-15 17:10:26,493 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:26.497 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 2 queries for chunk ml_fundamentals_model_evaluation
# 2026-01-15 17:10:26.498 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_best_practices
# 2026-01-15 17:10:27,005 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:27.008 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 2 queries for chunk ml_fundamentals_best_practices
# 2026-01-15 17:10:27.009 | INFO     | gaussia.schemas.generators:generate_dataset:586 - Generated 13 batches for chunk group (7 chunks)
# 2026-01-15 17:10:27.010 | INFO     | gaussia.schemas.generators:generate_dataset:600 - Generated 1 dataset(s) with 13 total batches
# Generated 13 queries:
#   - What are the primary types of machine learning algorithms for beginners?
#   - How can you balance model complexity and overfitting in a machine learning model?
#   - What are the three main types of machine learning?
#   - How do the different types of machine learning impact model performance?
#   - What are the key differences between supervised and unsupervised learning?

# %% [markdown]
# ## Chunk Selection Strategies
#
# Strategies control how chunks are selected and grouped during generation. By default, all chunks are processed sequentially into a single dataset.
#
# ### RandomSamplingStrategy
#
# Randomly samples chunks multiple times to create diverse test datasets:

# %%
async def generate_with_random_sampling():
    """Generate multiple datasets using random chunk sampling."""

    # Create a strategy that samples 3 random chunks, 2 times
    strategy = RandomSamplingStrategy(
        num_samples=2,  # Create 2 datasets
        chunks_per_sample=3,  # Each with 3 random chunks
        seed=42,  # For reproducibility
    )

    print(f"Strategy: {strategy}\n")

    datasets = await generator.generate_dataset(
        context_loader=loader,
        source=str(sample_file),
        assistant_id="ml-assistant",
        num_queries_per_chunk=2,
        selection_strategy=strategy,
    )

    print(f"Generated {len(datasets)} datasets:\n")
    for i, ds in enumerate(datasets):
        print(f"Dataset {i+1}:")
        print(f"  Session: {ds.session_id[:8]}...")
        print(f"  Queries: {len(ds.conversation)}")
        # Show chunk IDs from the queries
        chunk_ids = set(b.agentic.get("chunk_id", "N/A") for b in ds.conversation)
        print(f"  Chunks: {chunk_ids}\n")

    return datasets


# Execute
random_datasets = await generate_with_random_sampling()
# Out:
# 2026-01-15 17:10:27.021 | INFO     | gaussia.schemas.generators:generate_dataset:525 - Loading context from: ml_fundamentals.md
# 2026-01-15 17:10:27.023 | INFO     | gaussia.generators.context_loaders.local_markdown:load:275 - Loading 1 markdown file(s)
# 2026-01-15 17:10:27.025 | INFO     | gaussia.generators.context_loaders.local_markdown:_load_single_file:137 - Loading markdown file: ml_fundamentals.md
# 2026-01-15 17:10:27.027 | INFO     | gaussia.generators.context_loaders.local_markdown:load:282 - Created 7 total chunks from 1 file(s)
# 2026-01-15 17:10:27.028 | INFO     | gaussia.schemas.generators:generate_dataset:527 - Loaded 7 chunks from source
# 2026-01-15 17:10:27.029 | INFO     | gaussia.schemas.generators:generate_dataset:531 - Using chunk selection strategy: RandomSamplingStrategy(num_samples=2, chunks_per_sample=3, seed=42)
# 2026-01-15 17:10:27.031 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_model_evaluation
# Strategy: RandomSamplingStrategy(num_samples=2, chunks_per_sample=3, seed=42)
# 2026-01-15 17:10:27,517 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:27.521 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 2 queries for chunk ml_fundamentals_model_evaluation
# 2026-01-15 17:10:27.522 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_machine_learning_fundamentals
# 2026-01-15 17:10:27,949 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:27.952 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 2 queries for chunk ml_fundamentals_machine_learning_fundamentals
# 2026-01-15 17:10:27.953 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_best_practices
# 2026-01-15 17:10:28,525 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:28.528 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 2 queries for chunk ml_fundamentals_best_practices
# 2026-01-15 17:10:28.529 | INFO     | gaussia.schemas.generators:generate_dataset:586 - Generated 6 batches for chunk group (3 chunks)
# 2026-01-15 17:10:28.530 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_model_evaluation
# 2026-01-15 17:10:29,263 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:29.266 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 2 queries for chunk ml_fundamentals_model_evaluation
# 2026-01-15 17:10:29.267 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_supervised_learning
# 2026-01-15 17:10:29,869 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:29.872 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 2 queries for chunk ml_fundamentals_supervised_learning
# 2026-01-15 17:10:29.873 | DEBUG    | gaussia.schemas.generators:generate_queries:384 - Generating 2 queries for chunk ml_fundamentals_types_of_machine_learning
# 2026-01-15 17:10:30,384 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:30.387 | DEBUG    | gaussia.schemas.generators:generate_queries:415 - Generated 1 queries for chunk ml_fundamentals_types_of_machine_learning
# 2026-01-15 17:10:30.388 | INFO     | gaussia.schemas.generators:generate_dataset:586 - Generated 5 batches for chunk group (3 chunks)
# 2026-01-15 17:10:30.389 | INFO     | gaussia.schemas.generators:generate_dataset:600 - Generated 2 dataset(s) with 11 total batches
# Generated 2 datasets:
#
# Dataset 1:
#   Session: c2356905...
#   Queries: 6
#   Chunks: {'ml_fundamentals_model_evaluation', 'ml_fundamentals_machine_learning_fundamentals', 'ml_fundamentals_best_practices'}
#
# Dataset 2:
#   Session: 6541f97c...
#   Queries: 5
#   Chunks: {'ml_fundamentals_model_evaluation', 'ml_fundamentals_supervised_learning', 'ml_fundamentals_types_of_machine_learning'}

# %% [markdown]
# ## Conversation Mode
#
# Instead of generating independent queries, conversation mode creates coherent multi-turn conversations where each question builds on the previous ones:

# %%
async def generate_conversations():
    """Generate coherent multi-turn conversations."""

    print("Generating conversations (each turn builds on the previous)...\n")

    datasets = await generator.generate_dataset(
        context_loader=loader,
        source=str(sample_file),
        assistant_id="ml-assistant",
        num_queries_per_chunk=3,  # 3-turn conversations
        conversation_mode=True,  # Enable conversation mode
    )

    dataset = datasets[0]
    print(f"Generated {len(dataset.conversation)} conversation turns:\n")

    # Group by chunk to show conversation flow
    current_chunk = None
    for batch in dataset.conversation:
        chunk_id = batch.agentic.get("chunk_id", "N/A")
        turn_num = batch.agentic.get("turn_number", 0)
        builds_on = batch.agentic.get("builds_on", None)

        if chunk_id != current_chunk:
            print(f"\n--- Conversation for chunk: {chunk_id} ---")
            current_chunk = chunk_id

        print(f"  Turn {turn_num}: {batch.query}")
        if builds_on:
            print(f"         (builds on: {builds_on})")

    return datasets


# Execute
conversation_datasets = await generate_conversations()
# Out:
# 2026-01-15 17:10:30.401 | INFO     | gaussia.schemas.generators:generate_dataset:525 - Loading context from: ml_fundamentals.md
# 2026-01-15 17:10:30.403 | INFO     | gaussia.generators.context_loaders.local_markdown:load:275 - Loading 1 markdown file(s)
# 2026-01-15 17:10:30.404 | INFO     | gaussia.generators.context_loaders.local_markdown:_load_single_file:137 - Loading markdown file: ml_fundamentals.md
# 2026-01-15 17:10:30.404 | INFO     | gaussia.generators.context_loaders.local_markdown:load:282 - Created 7 total chunks from 1 file(s)
# 2026-01-15 17:10:30.405 | INFO     | gaussia.schemas.generators:generate_dataset:527 - Loaded 7 chunks from source
# 2026-01-15 17:10:30.405 | INFO     | gaussia.schemas.generators:generate_dataset:531 - Using chunk selection strategy: SequentialStrategy()
# 2026-01-15 17:10:30.406 | DEBUG    | gaussia.schemas.generators:generate_conversation:444 - Generating 3-turn conversation for chunk ml_fundamentals_machine_learning_fundamentals
# Generating conversations (each turn builds on the previous)...
# 2026-01-15 17:10:30,987 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:30.991 | DEBUG    | gaussia.schemas.generators:generate_conversation:482 - Generated 3 turns for chunk ml_fundamentals_machine_learning_fundamentals
# 2026-01-15 17:10:30.992 | DEBUG    | gaussia.schemas.generators:generate_conversation:444 - Generating 3-turn conversation for chunk ml_fundamentals_types_of_machine_learning
# 2026-01-15 17:10:31,582 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:31.587 | DEBUG    | gaussia.schemas.generators:generate_conversation:482 - Generated 3 turns for chunk ml_fundamentals_types_of_machine_learning
# 2026-01-15 17:10:31.588 | DEBUG    | gaussia.schemas.generators:generate_conversation:444 - Generating 3-turn conversation for chunk ml_fundamentals_supervised_learning
# 2026-01-15 17:10:32,535 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:32.539 | DEBUG    | gaussia.schemas.generators:generate_conversation:482 - Generated 3 turns for chunk ml_fundamentals_supervised_learning
# 2026-01-15 17:10:32.540 | DEBUG    | gaussia.schemas.generators:generate_conversation:444 - Generating 3-turn conversation for chunk ml_fundamentals_unsupervised_learning
# 2026-01-15 17:10:33,320 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:33.323 | DEBUG    | gaussia.schemas.generators:generate_conversation:482 - Generated 3 turns for chunk ml_fundamentals_unsupervised_learning
# 2026-01-15 17:10:33.324 | DEBUG    | gaussia.schemas.generators:generate_conversation:444 - Generating 3-turn conversation for chunk ml_fundamentals_reinforcement_learning
# 2026-01-15 17:10:33,966 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:33.969 | DEBUG    | gaussia.schemas.generators:generate_conversation:482 - Generated 3 turns for chunk ml_fundamentals_reinforcement_learning
# 2026-01-15 17:10:33.969 | DEBUG    | gaussia.schemas.generators:generate_conversation:444 - Generating 3-turn conversation for chunk ml_fundamentals_model_evaluation
# 2026-01-15 17:10:34,583 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:34.587 | DEBUG    | gaussia.schemas.generators:generate_conversation:482 - Generated 3 turns for chunk ml_fundamentals_model_evaluation
# 2026-01-15 17:10:34.588 | DEBUG    | gaussia.schemas.generators:generate_conversation:444 - Generating 3-turn conversation for chunk ml_fundamentals_best_practices
# 2026-01-15 17:10:35,299 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:35.302 | DEBUG    | gaussia.schemas.generators:generate_conversation:482 - Generated 3 turns for chunk ml_fundamentals_best_practices
# 2026-01-15 17:10:35.303 | INFO     | gaussia.schemas.generators:generate_dataset:586 - Generated 21 batches for chunk group (7 chunks)
# 2026-01-15 17:10:35.304 | INFO     | gaussia.schemas.generators:generate_dataset:600 - Generated 1 dataset(s) with 21 total batches
# Generated 21 conversation turns:
#
#
# --- Conversation for chunk: ml_fundamentals_machine_learning_fundamentals ---
#   Turn 1: What is machine learning?
#   Turn 2: Can you give an example of how machine learning is used in real life?
#          (builds on: ml_fundamentals_machine_learning_fundamentals_t1)
#   Turn 3: How does machine learning differ from traditional programming?
#          (builds on: ml_fundamentals_machine_learning_fundamentals_t2)
#
# --- Conversation for chunk: ml_fundamentals_types_of_machine_learning ---
#   Turn 1: What are the main categories of machine learning?
#   Turn 2: Can you explain supervised learning in more detail?
#          (builds on: ml_fundamentals_types_of_machine_learning_t1)
#   Turn 3: How does supervised learning compare to unsupervised learning in terms of data requirements?
#          (builds on: ml_fundamentals_types_of_machine_learning_t2)
#
# --- Conversation for chunk: ml_fundamentals_supervised_learning ---
#   Turn 1: What is the main purpose of using labeled training data?
#   Turn 2: How does labeled training data help in predicting outcomes?
#          (builds on: ml_fundamentals_supervised_learning_t1)
#   Turn 3: Can you provide an example of how labeled training data is used in classification and regression tasks?
#          (builds on: ml_fundamentals_supervised_learning_t2)
#
# --- Conversation for chunk: ml_fundamentals_unsupervised_learning ---
#   Turn 1: What are some common applications of unsupervised learning?
#   Turn 2: Can you give an example of how clustering works in unsupervised learning?
#          (builds on: ml_fundamentals_unsupervised_learning_t1)
#   Turn 3: How does dimensionality reduction relate to clustering in unsupervised learning?
#          (builds on: ml_fundamentals_unsupervised_learning_t2)
#
# --- Conversation for chunk: ml_fundamentals_reinforcement_learning ---
#   Turn 1: What is learning?
#   Turn 2: How does an agent learn through interaction with the environment?
#          (builds on: ml_fundamentals_reinforcement_learning_t1)
#   Turn 3: Can you give an example of an agent maximizing cumulative reward?
#          (builds on: ml_fundamentals_reinforcement_learning_t2)
#
# --- Conversation for chunk: ml_fundamentals_model_evaluation ---
#   Turn 1: What are the key metrics used to evaluate machine learning models?
#   Turn 2: Can you explain the difference between accuracy and precision?
#          (builds on: ml_fundamentals_model_evaluation_t1)
#   Turn 3: How do recall and F1 score relate to each other in the context of model evaluation?
#          (builds on: ml_fundamentals_model_evaluation_t2)
#
# --- Conversation for chunk: ml_fundamentals_best_practices ---
#   Turn 1: What are the general steps for splitting data into train and test sets?
#   Turn 2: How can we use cross-validation to evaluate our model's performance?
#          (builds on: ml_fundamentals_best_practices_t1)
#   Turn 3: What are some common techniques to monitor for overfitting in machine learning?
#          (builds on: ml_fundamentals_best_practices_t2)

# %% [markdown]
# ### Combined: Random Sampling + Conversation Mode
#
# You can combine strategies with conversation mode to create diverse conversation-based test sets:

# %%
async def generate_random_conversations():
    """Combine random sampling with conversation mode."""

    strategy = RandomSamplingStrategy(
        num_samples=2,
        chunks_per_sample=2,
        seed=42,
    )

    print("Generating 2 datasets with 2 random chunks each (conversation mode)...\n")

    datasets = await generator.generate_dataset(
        context_loader=loader,
        source=str(sample_file),
        assistant_id="ml-assistant",
        num_queries_per_chunk=2,  # 2-turn conversations
        selection_strategy=strategy,
        conversation_mode=True,
    )

    for i, ds in enumerate(datasets):
        print(f"Dataset {i+1} ({len(ds.conversation)} turns):")
        for batch in ds.conversation[:4]:  # Show first 4 turns
            chunk = batch.agentic.get("chunk_id", "N/A")[:15]
            turn = batch.agentic.get("turn_number", 0)
            print(f"  [{chunk}] T{turn}: {batch.query[:50]}...")
        print()

    return datasets


# Execute
combined_datasets = await generate_random_conversations()
# Out:
# 2026-01-15 17:10:35.309 | INFO     | gaussia.schemas.generators:generate_dataset:525 - Loading context from: ml_fundamentals.md
# 2026-01-15 17:10:35.310 | INFO     | gaussia.generators.context_loaders.local_markdown:load:275 - Loading 1 markdown file(s)
# 2026-01-15 17:10:35.311 | INFO     | gaussia.generators.context_loaders.local_markdown:_load_single_file:137 - Loading markdown file: ml_fundamentals.md
# 2026-01-15 17:10:35.312 | INFO     | gaussia.generators.context_loaders.local_markdown:load:282 - Created 7 total chunks from 1 file(s)
# 2026-01-15 17:10:35.313 | INFO     | gaussia.schemas.generators:generate_dataset:527 - Loaded 7 chunks from source
# 2026-01-15 17:10:35.313 | INFO     | gaussia.schemas.generators:generate_dataset:531 - Using chunk selection strategy: RandomSamplingStrategy(num_samples=2, chunks_per_sample=2, seed=42)
# 2026-01-15 17:10:35.314 | DEBUG    | gaussia.schemas.generators:generate_conversation:444 - Generating 2-turn conversation for chunk ml_fundamentals_model_evaluation
# Generating 2 datasets with 2 random chunks each (conversation mode)...
# 2026-01-15 17:10:36,016 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:36.019 | DEBUG    | gaussia.schemas.generators:generate_conversation:482 - Generated 2 turns for chunk ml_fundamentals_model_evaluation
# 2026-01-15 17:10:36.020 | DEBUG    | gaussia.schemas.generators:generate_conversation:444 - Generating 2-turn conversation for chunk ml_fundamentals_machine_learning_fundamentals
# 2026-01-15 17:10:36,733 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:36.736 | DEBUG    | gaussia.schemas.generators:generate_conversation:482 - Generated 2 turns for chunk ml_fundamentals_machine_learning_fundamentals
# 2026-01-15 17:10:36.738 | INFO     | gaussia.schemas.generators:generate_dataset:586 - Generated 4 batches for chunk group (2 chunks)
# 2026-01-15 17:10:36.739 | DEBUG    | gaussia.schemas.generators:generate_conversation:444 - Generating 2-turn conversation for chunk ml_fundamentals_machine_learning_fundamentals
# 2026-01-15 17:10:37,346 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:37.349 | DEBUG    | gaussia.schemas.generators:generate_conversation:482 - Generated 2 turns for chunk ml_fundamentals_machine_learning_fundamentals
# 2026-01-15 17:10:37.350 | DEBUG    | gaussia.schemas.generators:generate_conversation:444 - Generating 2-turn conversation for chunk ml_fundamentals_model_evaluation
# 2026-01-15 17:10:37,961 - httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-01-15 17:10:37.963 | DEBUG    | gaussia.schemas.generators:generate_conversation:482 - Generated 2 turns for chunk ml_fundamentals_model_evaluation
# 2026-01-15 17:10:37.963 | INFO     | gaussia.schemas.generators:generate_dataset:586 - Generated 4 batches for chunk group (2 chunks)
# 2026-01-15 17:10:37.964 | INFO     | gaussia.schemas.generators:generate_dataset:600 - Generated 2 dataset(s) with 8 total batches
# Dataset 1 (4 turns):
#   [ml_fundamentals] T1: What are the key metrics used to evaluate machine ...
#   [ml_fundamentals] T2: Can you explain the difference between precision a...
#   [ml_fundamentals] T1: What is machine learning?...
#   [ml_fundamentals] T2: How does it differ from traditional programming?...
#
# Dataset 2 (4 turns):
#   [ml_fundamentals] T1: What is machine learning?...
#   [ml_fundamentals] T2: How does it differ from traditional programming?...
#   [ml_fundamentals] T1: What are the key metrics used to evaluate ML model...
#   [ml_fundamentals] T2: Can you explain the difference between precision a...

# %% [markdown]
# ## Save Generated Dataset

# %%
# Save dataset to JSON
output_file = Path("./generated_tests_groq.json")
with open(output_file, "w") as f:
    json.dump(dataset.model_dump(), f, indent=2)

print(f"Dataset saved to: {output_file}")
# Out:
# Dataset saved to: generated_tests_groq.json

# %% [markdown]
# ## Available Groq Models
#
# Check [Groq Console](https://console.groq.com/docs/models) for the latest available models.

# %% [markdown]
# ## Cleanup

# %%
# Clean up sample files
if sample_file.exists():
    sample_file.unlink()
if output_file.exists():
    output_file.unlink()
print("Cleanup completed")
# Out:
# Cleanup completed
